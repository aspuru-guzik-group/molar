# %% [markdown]
# # Event sourcing
#
# Instead of writing directly to the tables, the client writes to an extra table, the `eventstore`, to keep track of all the changes. This allows now only to keep track of the changes, but also allows to revert the database to what it was at any point of time.
#
# Here is what it looks like:

# %%
import mdb

client = mdb.MDBClient(hostname='localhost',
                       username='postgres',
                       password='',
                       database='mdb')

es = client.get('eventstore')
es
# Out:
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/dialects/postgresql/base.py:3010: SAWarning: Did not recognize type 'xml' of column 'xdl'
#   "Did not recognize type '%s' of column '%s'" % (attype, name)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.conformer, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule_fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.software, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.calculation, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.calculation_type, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.alembic_version, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synthesis_machine, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.lab, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.xy_data, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.experiment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.experiment_machine, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.experiment_type, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synthesis, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.data_unit, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synth_molecule, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synth_fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
#                   type  id                                  uuid  \
# 0             molecule  18  e3dde6c2-ab0c-4c77-9d55-e52d58a1425d
# 1              xy_data  17  4d78fcc7-27d1-419d-8b0d-a882f52ac962
# 2            data_unit  16  69cde87a-5fe2-428e-b129-4dad9b8bbe4f
# 3           experiment  15  0e0e76e9-6f2f-40fd-84e4-cdcc05de0f8e
# 4   experiment_machine  14  455250de-954e-47e9-b541-55215d07d881
# 5      experiment_type  13  3cc2423a-7a6a-4aa7-8edc-c1b41d5e223d
# 6            synthesis  12  bd8e2ba9-5f1a-40f8-8f9b-af4c47b70212
# 7            synthesis  11  bd8e2ba9-5f1a-40f8-8f9b-af4c47b70212
# 8             molecule  10  c053009a-9b1d-44a7-8267-f5befdb03eb0
# 9    molecule_fragment   7  cf8151dd-2e19-43a3-a175-4e3293f858d5
# 10   molecule_fragment   9  a262f5e8-2286-41a6-81b6-371e08f1d4d3
# 11   molecule_fragment   8  25b3209f-4266-449b-9223-666fcba592e8
# 12            molecule   6  c053009a-9b1d-44a7-8267-f5befdb03eb0
# 13            fragment   5  10e88031-39e6-4a60-a760-55ae2d142e43
# 14            fragment   4  e23166bb-88c4-464b-ac27-384e7ac7a475
# 15            fragment   3  93d1dd17-8f7b-4f61-8cb4-dbeab0e7730f
# 16   synthesis_machine   2  27811cc0-6c7b-4fb0-b679-435e1e280c1a
# 17                 lab   1  cd599368-4fd8-4db5-b0d2-d70b8af2a1b5
#
#                                                  data   event  \
# 0                                   {'smiles': 'DEF'}  create
# 1   {'x': [0.0, 0.10101010101010101, 0.20202020202...  create
# 2                            {'name': 'stupid_units'}  create
# 3   {'notes': '', 'metadata': {'param1': 100, 'kno...  create
# 4   {'name': 'Mad NMR', 'lab_id': 'cd599368-4fd8-4...  create
# 5                                     {'name': 'NMR'}  create
# 6   {'notes': '
# # Synthesis of ABC
#
# Everything wen...  update
# 7   {'hid': 'MAD_2020-02-17_0', 'xdl': '<xdl><reci...  create
# 8                   {'smiles': 'ABC', 'metadata': {}}  update
# 9   {'order': 0, 'fragment_id': '93d1dd17-8f7b-4f6...  create
# 10  {'order': 2, 'fragment_id': '10e88031-39e6-4a6...  create
# 11  {'order': 1, 'fragment_id': 'e23166bb-88c4-464...  create
# 12                        {'smiles': 'A-UGLY-TYPO-C'}  create
# 13                                    {'smiles': 'C'}  create
# 14                                    {'smiles': 'B'}  create
# 15                                    {'smiles': 'A'}  create
# 16  {'name': 'Mad Machine Doing Chemistry', 'lab_i...  create
# 17           {'name': 'Mad Lab', 'short_name': 'MAD'}  create
#
#                     timestamp
# 0  2020-02-17 03:10:16.722259
# 1  2020-02-17 03:10:00.699414
# 2  2020-02-17 03:10:00.647864
# 3  2020-02-17 03:09:59.145749
# 4  2020-02-17 03:09:59.105570
# 5  2020-02-17 03:09:58.637635
# 6  2020-02-17 03:09:57.003529
# 7  2020-02-17 03:09:55.410886
# 8  2020-02-17 03:09:48.810674
# 9  2020-02-17 03:09:48.748453
# 10 2020-02-17 03:09:48.748453
# 11 2020-02-17 03:09:48.748453
# 12 2020-02-17 03:09:48.673496
# 13 2020-02-17 03:09:48.631793
# 14 2020-02-17 03:09:48.571496
# 15 2020-02-17 03:09:48.509270
# 16 2020-02-17 03:09:48.400127
# 17 2020-02-17 03:09:48.219183

# %% [markdown]
# ## Rollback
#
# To revert at a specific point of time, the client implements a method `rollback`.
#
# Here we will revert the database to everything before the timestamp `2020-02-17 00:21:59.810407` (creation of data_unit).

# %%
client.rollback(before=es.at[3, 'timestamp'].to_pydatetime())

# %%
client.get('eventstore').sort_values(by=['id'])
# Out:
#            event                                               data  id  \
# 49        create           {'name': 'Mad Lab', 'short_name': 'MAD'}   1
# 48        create  {'name': 'Mad Machine Doing Chemistry', 'lab_i...   2
# 47        create                                    {'smiles': 'A'}   3
# 46        create                                    {'smiles': 'B'}   4
# 45        create                                    {'smiles': 'C'}   5
# 44        create                        {'smiles': 'A-UGLY-TYPO-C'}   6
# 43        create  {'order': 0, 'fragment_id': '93d1dd17-8f7b-4f6...   7
# 41        create  {'order': 1, 'fragment_id': 'e23166bb-88c4-464...   8
# 42        create  {'order': 2, 'fragment_id': '10e88031-39e6-4a6...   9
# 40        update                  {'smiles': 'ABC', 'metadata': {}}  10
# 39        create  {'hid': 'MAD_2020-02-17_0', 'xdl': '<xdl><reci...  11
# 38        update  {'notes': '
# # Synthesis of ABC
#
# Everything wen...  12
# 37        create                                    {'name': 'NMR'}  13
# 36        create  {'name': 'Mad NMR', 'lab_id': 'cd599368-4fd8-4...  14
# 35        create  {'notes': '', 'metadata': {'param1': 100, 'kno...  15
# 34        create                           {'name': 'stupid_units'}  16
# 33        create  {'x': [0.0, 0.10101010101010101, 0.20202020202...  17
# 32        create                                  {'smiles': 'DEF'}  18
# 0       rollback           {'before': '2020-02-17T03:09:59.145749'}  19
# 19        delete                                                 {}  20
# 20        delete                                                 {}  21
# 21        delete                                                 {}  22
# 22        delete                                                 {}  23
# 23        delete                                                 {}  24
# 24        delete                                                 {}  25
# 25        delete                                                 {}  26
# 26        delete                                                 {}  27
# 27        delete                                                 {}  28
# 28        delete                                                 {}  29
# 29        delete                                                 {}  30
# 30        delete                                                 {}  31
# 31        delete                                                 {}  32
# 1         delete                                                 {}  33
# 2         delete                                                 {}  34
# 3         delete                                                 {}  35
# 4         create           {'name': 'Mad Lab', 'short_name': 'MAD'}  36
# 5         create  {'name': 'Mad Machine Doing Chemistry', 'lab_i...  37
# 6         create                                    {'smiles': 'A'}  38
# 7         create                                    {'smiles': 'B'}  39
# 8         create                                    {'smiles': 'C'}  40
# 9         create                        {'smiles': 'A-UGLY-TYPO-C'}  41
# 10        create  {'order': 0, 'fragment_id': '93d1dd17-8f7b-4f6...  42
# 11        create  {'order': 1, 'fragment_id': 'e23166bb-88c4-464...  43
# 12        create  {'order': 2, 'fragment_id': '10e88031-39e6-4a6...  44
# 13        update                  {'smiles': 'ABC', 'metadata': {}}  45
# 14        create  {'hid': 'MAD_2020-02-17_0', 'xdl': '<xdl><reci...  46
# 15        update  {'notes': '
# # Synthesis of ABC
#
# Everything wen...  47
# 16        create                                    {'name': 'NMR'}  48
# 17        create  {'name': 'Mad NMR', 'lab_id': 'cd599368-4fd8-4...  49
# 18  rollback-end           {'before': '2020-02-17T03:09:59.145749'}  50
#
#                   type                                  uuid  \
# 49                 lab  cd599368-4fd8-4db5-b0d2-d70b8af2a1b5
# 48   synthesis_machine  27811cc0-6c7b-4fb0-b679-435e1e280c1a
# 47            fragment  93d1dd17-8f7b-4f61-8cb4-dbeab0e7730f
# 46            fragment  e23166bb-88c4-464b-ac27-384e7ac7a475
# 45            fragment  10e88031-39e6-4a60-a760-55ae2d142e43
# 44            molecule  c053009a-9b1d-44a7-8267-f5befdb03eb0
# 43   molecule_fragment  cf8151dd-2e19-43a3-a175-4e3293f858d5
# 41   molecule_fragment  25b3209f-4266-449b-9223-666fcba592e8
# 42   molecule_fragment  a262f5e8-2286-41a6-81b6-371e08f1d4d3
# 40            molecule  c053009a-9b1d-44a7-8267-f5befdb03eb0
# 39           synthesis  bd8e2ba9-5f1a-40f8-8f9b-af4c47b70212
# 38           synthesis  bd8e2ba9-5f1a-40f8-8f9b-af4c47b70212
# 37     experiment_type  3cc2423a-7a6a-4aa7-8edc-c1b41d5e223d
# 36  experiment_machine  455250de-954e-47e9-b541-55215d07d881
# 35          experiment  0e0e76e9-6f2f-40fd-84e4-cdcc05de0f8e
# 34           data_unit  69cde87a-5fe2-428e-b129-4dad9b8bbe4f
# 33             xy_data  4d78fcc7-27d1-419d-8b0d-a882f52ac962
# 32            molecule  e3dde6c2-ab0c-4c77-9d55-e52d58a1425d
# 0                 None                                  None
# 19            molecule  e3dde6c2-ab0c-4c77-9d55-e52d58a1425d
# 20             xy_data  4d78fcc7-27d1-419d-8b0d-a882f52ac962
# 21           data_unit  69cde87a-5fe2-428e-b129-4dad9b8bbe4f
# 22          experiment  0e0e76e9-6f2f-40fd-84e4-cdcc05de0f8e
# 23  experiment_machine  455250de-954e-47e9-b541-55215d07d881
# 24     experiment_type  3cc2423a-7a6a-4aa7-8edc-c1b41d5e223d
# 25           synthesis  bd8e2ba9-5f1a-40f8-8f9b-af4c47b70212
# 26   molecule_fragment  a262f5e8-2286-41a6-81b6-371e08f1d4d3
# 27   molecule_fragment  25b3209f-4266-449b-9223-666fcba592e8
# 28   molecule_fragment  cf8151dd-2e19-43a3-a175-4e3293f858d5
# 29            molecule  c053009a-9b1d-44a7-8267-f5befdb03eb0
# 30            fragment  10e88031-39e6-4a60-a760-55ae2d142e43
# 31            fragment  e23166bb-88c4-464b-ac27-384e7ac7a475
# 1             fragment  93d1dd17-8f7b-4f61-8cb4-dbeab0e7730f
# 2    synthesis_machine  27811cc0-6c7b-4fb0-b679-435e1e280c1a
# 3                  lab  cd599368-4fd8-4db5-b0d2-d70b8af2a1b5
# 4                  lab  cd599368-4fd8-4db5-b0d2-d70b8af2a1b5
# 5    synthesis_machine  27811cc0-6c7b-4fb0-b679-435e1e280c1a
# 6             fragment  93d1dd17-8f7b-4f61-8cb4-dbeab0e7730f
# 7             fragment  e23166bb-88c4-464b-ac27-384e7ac7a475
# 8             fragment  10e88031-39e6-4a60-a760-55ae2d142e43
# 9             molecule  c053009a-9b1d-44a7-8267-f5befdb03eb0
#