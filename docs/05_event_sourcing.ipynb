# %% [markdown]
# # Event sourcing
#
# MapleDB uses `eventstore` instead of `active records`. This means that instead of writing directly to the tables, the client will write the changes it wants to perform to an extra table, the `eventstore`, to keep track of every cahnges. This allows not only to keep track of these changes, but also to revert the database to any point of time if needed.
#
# While event sourcing is very good method to avoid data-loss, it does not protect a database against hardware failure. Keep this in mind when setting up your server to host MapleDB.

# %%
import mdb

client = mdb.MDBClient(hostname='localhost',
                       username='postgres',
                       password='',
                       database='mdb')

es = client.get('eventstore')
es
# Out:
#      event                                               data  \
# 0   create  {'smiles': 'DEF', 'molecule_type_id': '47313a9...
# 1   create  {'x': [0.0, 0.10101010101010101, 0.20202020202...
# 2   create                           {'name': 'stupid_units'}
# 3   create  {'notes': '', 'metadata': {'param1': 100, 'kno...
# 4   create  {'make': 'Super NMR', 'name': 'Mad NMR', 'mode...
# 5   create                                    {'name': 'NMR'}
# 6   update  {'notes': '
# # Synthesis of ABC
#
# Everything wen...
# 7   create  {'hid': 'MAD_2020-04-01_0', 'xdl': '<xdl><reci...
# 8   update  {'cas': '13283-31-3', 'cid': 6331.0, 'inchi': ...
# 9   update  {'cas': None, 'cid': None, 'inchi': None, 'smi...
# 10  update  {'cas': '74-82-8', 'cid': 297.0, 'inchi': 'InC...
# 11  update  {'cas': None, 'cid': None, 'inchi': None, 'smi...
# 12  create  {'order': 0, 'product_molecule_id': '6da175a0-...
# 13  create  {'order': 2, 'product_molecule_id': '6da175a0-...
# 14  create  {'order': 1, 'product_molecule_id': '6da175a0-...
# 15  create  {'smiles': 'A-UGLY-TYPO-C', 'molecule_type_id'...
# 16  create                    {'name': 'rule_based_molecule'}
# 17  create  {'cas': '74-82-8', 'cid': 297, 'inchi': 'InChI...
# 18  create  {'cas': '13283-31-3', 'cid': 6331, 'inchi': 'I...
# 19  create  {'smiles': 'A', 'molecule_type_id': '4dcfb667-...
# 20  create                               {'name': 'fragment'}
# 21  create  {'make': 'MadChem', 'name': 'Mad Machine Doing...
# 22  create           {'name': 'Mad Lab', 'short_name': 'MAD'}
#
#                                     uuid  id                type  \
# 0   2e451d97-3e56-4798-b493-fc3574a7b13f  23            molecule
# 1   8317394a-45f6-459b-940a-9601aef28cf4  22             xy_data
# 2   a6e79a81-c91b-49d6-a620-d8019b805ef6  21           data_unit
# 3   6e28b0ba-184b-4f0d-b400-c13d3b2909a6  20          experiment
# 4   247f4f20-903a-430a-8063-7541a37c42dc  19  experiment_machine
# 5   59ed84db-0671-46cf-b22c-da8a83115dbf  18     experiment_type
# 6   fe4d8183-5140-475b-b0e7-811bcc2db502  17           synthesis
# 7   fe4d8183-5140-475b-b0e7-811bcc2db502  16           synthesis
# 8   1338c13b-8ec0-455d-806e-549256c5e2b4  14            molecule
# 9   0b0a88df-4d69-4eea-88a9-8c3bceeeeba0  15            molecule
# 10  5762121f-fd3d-4766-bdfd-4396079bb4e6  13            molecule
# 11  6da175a0-af06-42b4-95bf-dfb59d87d16e  12            molecule
# 12  31fe9189-22f7-4453-b94a-e6d9a1f20256   9   molecule_molecule
# 13  bb9072d5-dd06-47f4-a6f5-3a65d6aada0f  11   molecule_molecule
# 14  c6fa2885-1975-49a1-a4b2-dfcab4a85a4f  10   molecule_molecule
# 15  6da175a0-af06-42b4-95bf-dfb59d87d16e   8            molecule
# 16  47313a9d-1312-4c22-b57c-38b8bf8dd978   7       molecule_type
# 17  5762121f-fd3d-4766-bdfd-4396079bb4e6   6            molecule
# 18  1338c13b-8ec0-455d-806e-549256c5e2b4   5            molecule
# 19  0b0a88df-4d69-4eea-88a9-8c3bceeeeba0   4            molecule
# 20  4dcfb667-5c9c-4d4f-a123-97cd8bee0513   3       molecule_type
# 21  59aa61d2-bb84-43ea-a58c-11325dfefe57   2   synthesis_machine
# 22  5541b619-c181-4647-98b6-79516ee24800   1                 lab
#
#                     timestamp
# 0  2020-04-01 09:23:45.794141
# 1  2020-04-01 09:21:17.498280
# 2  2020-04-01 09:21:17.435500
# 3  2020-04-01 09:21:17.363519
# 4  2020-04-01 09:21:17.291960
# 5  2020-04-01 09:21:17.111681
# 6  2020-04-01 09:21:16.816755
# 7  2020-04-01 09:21:16.664410
# 8  2020-04-01 09:21:16.419759
# 9  2020-04-01 09:21:16.419759
# 10 2020-04-01 09:21:16.419759
# 11 2020-04-01 09:21:16.182975
# 12 2020-04-01 09:21:16.134816
# 13 2020-04-01 09:21:16.134816
# 14 2020-04-01 09:21:16.134816
# 15 2020-04-01 09:21:14.152737
# 16 2020-04-01 09:21:14.142189
# 17 2020-04-01 09:20:57.534246
# 18 2020-04-01 09:20:41.715173
# 19 2020-04-01 09:20:25.475240
# 20 2020-04-01 09:20:25.431244
# 21 2020-04-01 09:20:25.327287
# 22 2020-04-01 09:20:25.145175

# %% [markdown]
# ## Rollback
#
# It is possible to `rollback` the database to revert to any point of time. To do so, the rollback method can be used:

# %%
client.rollback(before=es.at[3, 'timestamp'].to_pydatetime())

# %%
client.get('eventstore').sort_values(by=['id'])
# Out:
#            event                                               data  id  \
# 61        create           {'name': 'Mad Lab', 'short_name': 'MAD'}   1
# 60        create  {'make': 'MadChem', 'name': 'Mad Machine Doing...   2
# 59        create                               {'name': 'fragment'}   3
# 58        create  {'smiles': 'A', 'molecule_type_id': '4dcfb667-...   4
# 57        create  {'cas': '13283-31-3', 'cid': 6331, 'inchi': 'I...   5
# ..           ...                                                ...  ..
# 19        create  {'hid': 'MAD_2020-04-01_0', 'xdl': '<xdl><reci...  58
# 20        update  {'notes': '
# # Synthesis of ABC
#
# Everything wen...  59
# 21        create                                    {'name': 'NMR'}  60
# 22        create  {'make': 'Super NMR', 'name': 'Mad NMR', 'mode...  61
# 23  rollback-end           {'before': '2020-04-01T09:21:17.363519'}  62
#
#                                     uuid                type  \
# 61  5541b619-c181-4647-98b6-79516ee24800                 lab
# 60  59aa61d2-bb84-43ea-a58c-11325dfefe57   synthesis_machine
# 59  4dcfb667-5c9c-4d4f-a123-97cd8bee0513       molecule_type
# 58  0b0a88df-4d69-4eea-88a9-8c3bceeeeba0            molecule
# 57  1338c13b-8ec0-455d-806e-549256c5e2b4            molecule
# ..                                   ...                 ...
# 19  fe4d8183-5140-475b-b0e7-811bcc2db502           synthesis
# 20  fe4d8183-5140-475b-b0e7-811bcc2db502           synthesis
# 21  59ed84db-0671-46cf-b22c-da8a83115dbf     experiment_type
# 22  247f4f20-903a-430a-8063-7541a37c42dc  experiment_machine
# 23                                  None                None
#
#                     timestamp
# 61 2020-04-01 09:20:25.145175
# 60 2020-04-01 09:20:25.327287
# 59 2020-04-01 09:20:25.431244
# 58 2020-04-01 09:20:25.475240
# 57 2020-04-01 09:20:41.715173
# ..                        ...
# 19 2020-04-01 09:24:29.687648
# 20 2020-04-01 09:24:29.687648
# 21 2020-04-01 09:24:29.687648
# 22 2020-04-01 09:24:29.687648
# 23 2020-04-01 09:24:29.687648
#
# [62 rows x 6 columns]

# %% [markdown]
# We can see here from the event `rollback` everything is deleted and then the event are sequentially repeated until the we reach the given timestamp.
