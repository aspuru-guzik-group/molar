# %% [markdown]
# # Examples

# %%
from goldmine import GoldmineClient

client = GoldmineClient('localhost', 'postgres', '', 'molecdb')
# Out:
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.calculation, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.conformation, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.software, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.user, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule_fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/gm/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.atom, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)

# %% [markdown]
# ## Get, Add, Update, Delete

# %% [markdown]
# There are four main methods in the client: `add`, `get`, `update` and `delete`. They have been made to be relatively easy to use and accept many different inputs.
#
# Let say we want to add a molecule. To do so, we can use the `add` method, and read the results with `get`. The results is a pandas.DataFrame that corresponds to the table `molecule`. Indeed with this method you have to be aware of the scheme of the database.

# %%
data = {'smiles': 'C1C=CC=C1'}
client.add('molecule', data)
client.get('molecule')
# Out:
#                   created_on  id properties     smiles  \
# 0 2019-06-24 12:50:04.141505   1         {}  C1C=CC=C1
#
#                   updated_on                                  uuid
# 0 2019-06-24 12:50:04.141505  d12075e9-b918-4b33-8135-ae2c3b04337b

# %% [markdown]
# If we want to work with a pandas.DataFrame as an input, we can just change the input. The column of the dataframe have to corresponds to the fields of the sql table.

# %%
import pandas as pd

df = pd.DataFrame([{'smiles': 'C#N'}, {'smiles': 'CC'}])
df.head()
# Out:
#   smiles
# 0    C#N
# 1     CC

# %%
client.add('molecule', df)
df = client.get('molecule')
df
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 60.01it/s]
#                   created_on  id properties     smiles  \
# 0 2019-06-24 12:50:04.141505   1         {}  C1C=CC=C1
# 1 2019-06-24 12:50:04.215284   2         {}        C#N
# 2 2019-06-24 12:50:05.663229   3         {}         CC
#
#                   updated_on                                  uuid
# 0 2019-06-24 12:50:04.141505  d12075e9-b918-4b33-8135-ae2c3b04337b
# 1 2019-06-24 12:50:04.215284  00f65f13-06fb-420e-b535-657d2a714f0a
# 2 2019-06-24 12:50:05.663229  2d312c7e-b44d-4252-9110-673fc963f505

# %% [markdown]
# It is also possile to get a dataframe of a table, change some values and set it back to the database.

# %%
df.at[0, 'properties'] = {'new_prop': 'prop_value'}
df
# Out:
#                   created_on  id                  properties     smiles  \
# 0 2019-06-24 12:50:04.141505   1  {'new_prop': 'prop_value'}  C1C=CC=C1
# 1 2019-06-24 12:50:04.215284   2                          {}        C#N
# 2 2019-06-24 12:50:05.663229   3                          {}         CC
#
#                   updated_on                                  uuid
# 0 2019-06-24 12:50:04.141505  d12075e9-b918-4b33-8135-ae2c3b04337b
# 1 2019-06-24 12:50:04.215284  00f65f13-06fb-420e-b535-657d2a714f0a
# 2 2019-06-24 12:50:05.663229  2d312c7e-b44d-4252-9110-673fc963f505

# %%
client.update('molecule', df)
df = client.get('molecule')
df
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 959.72it/s]
#                   created_on  id                  properties     smiles  \
# 0 2019-06-24 12:50:04.141505   1  {'new_prop': 'prop_value'}  C1C=CC=C1
# 1 2019-06-24 12:50:04.215284   2                          {}        C#N
# 2 2019-06-24 12:50:05.663229   3                          {}         CC
#
#                   updated_on                                  uuid
# 0 2019-06-24 12:50:05.696646  d12075e9-b918-4b33-8135-ae2c3b04337b
# 1 2019-06-24 12:50:05.696646  00f65f13-06fb-420e-b535-657d2a714f0a
# 2 2019-06-24 12:50:05.696646  2d312c7e-b44d-4252-9110-673fc963f505

# %% [markdown]
# The `delete` method can take either a single uuid or a list of uuids:

# %%
df = client.get('molecule')
client.delete('molecule', df['uuid'].tolist())
client.get('molecule')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Objects with relations and helper methods
#
# Of course, `add`, `get`, `update` and `delete` don't capture everything. The relationships between objects do not appear on the pandas.DataFrame and it may be burdensome to add these relationship by hand. This is why some helper methods have been implemented.
#
# It is recommended you use this method when you are adding data to the database instead of the base methods for all objects that have relationships.

# %%
client.add_molecule(fragment=['C#N', 'CCC'], smiles='CCCC#N')
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 89.88it/s]

# %%
# two fragments have been added
client.get('fragment')
# Out:
#                   created_on  id properties smiles                 updated_on  \
# 0 2019-06-24 12:50:08.580389   1         {}    C#N 2019-06-24 12:50:08.580389
# 1 2019-06-24 12:50:08.622059   2         {}    CCC 2019-06-24 12:50:08.622059
#
#                                    uuid
# 0  f89b3c7a-8350-48af-811c-4821448df1a5
# 1  b2ea629f-88c5-4f7d-a220-ccd4de8b0ab7

# %%
# as well as the molecule
client.get('molecule')
# Out:
#                   created_on  id properties  smiles  \
# 0 2019-06-24 12:50:07.814670   4         {}  CCCC#N
#
#                   updated_on                                  uuid
# 0 2019-06-24 12:50:07.814670  024c4524-d24b-497b-b01a-71f29cbd5e8f

# %%
# and the relationship binding the two
client.get('molecule_fragment')
# Out:
#                   created_on                           fragment_id  id  \
# 0 2019-06-24 12:50:08.649079  f89b3c7a-8350-48af-811c-4821448df1a5   1
# 1 2019-06-24 12:50:08.678458  b2ea629f-88c5-4f7d-a220-ccd4de8b0ab7   2
#
#                             molecule_id  order                 updated_on  \
# 0  024c4524-d24b-497b-b01a-71f29cbd5e8f      0 2019-06-24 12:50:08.649079
# 1  024c4524-d24b-497b-b01a-71f29cbd5e8f      1 2019-06-24 12:50:08.678458
#
#                                    uuid
# 0  747fbf3c-64ca-4cc9-ad10-41e73d15910a
# 1  e71b32b7-e752-4644-b248-5f556cbf903a

# %% [markdown]
# ## Filtering
#
# All of this would be rather useless if we did not have an efficient way of filtering data. This is made rather easy thanks to the postgresql database. By using `client.get_models()` you get the scheme of the database and filter them as if they were python objects:

# %%
models = client.get_models()

# %%
client.get('fragment', filters=[models.fragment.smiles == 'C#N'])
# Out:
#                   created_on  id properties smiles                 updated_on  \
# 0 2019-06-24 12:50:08.580389   1         {}    C#N 2019-06-24 12:50:08.580389
#
#                                    uuid
# 0  f89b3c7a-8350-48af-811c-4821448df1a5

# %% [markdown]
# You can also do more complex filtering, joining tables that are related:

# %%
client.get(['molecule', 'molecule_fragment', 'fragment'], filters=[models.fragment.smiles == 'C#N', 
                                                                   models.molecule_fragment.order == 0])
# Out:
#                   created_on  id properties  smiles  \
# 0 2019-06-24 12:50:07.814670   4         {}  CCCC#N
#
#                   updated_on                                  uuid
# 0 2019-06-24 12:50:07.814670  024c4524-d24b-497b-b01a-71f29cbd5e8f

# %% [markdown]
# In the here-above example, you only get the first table, because a pandas.DataFrame is not really well suited to deal with relational objects. Fortunately, you can also output a `sqlalchemy` object that will incorportate this mapping.

# %%
molecule = client.get(['molecule', 'molecule_fragment', 'fragment'], dataframe=False)
print(molecule[0].smiles)
print(molecule[0].molecule_fragment_collection[0].order)
print(molecule[0].molecule_fragment_collection[0].fragment.smiles)
# Out:
# CCCC#N
# 0
# C#N

# %% [markdown]
# ## Rollback
#
# The advantage of using event sourcing is that you can rollback at any point of time. Here is a quick example:

# %%
client.get('eventstore')
# Out:
#                                                  data   event  id  \
# 0                    {'id': 1, 'smiles': 'C1C=CC=C1'}  create   1
# 1                          {'id': 2, 'smiles': 'C#N'}  create   2
# 2                           {'id': 3, 'smiles': 'CC'}  create   3
# 3   {'id': 1, 'smiles': 'C1C=CC=C1', 'properties':...  update   4
# 4        {'id': 2, 'smiles': 'C#N', 'properties': {}}  update   5
# 5         {'id': 3, 'smiles': 'CC', 'properties': {}}  update   6
# 6                                                None  delete   7
# 7                                                None  delete   8
# 8                                                None  delete   9
# 9                       {'id': 4, 'smiles': 'CCCC#N'}  create  10
# 10                         {'id': 1, 'smiles': 'C#N'}  create  11
# 11                         {'id': 2, 'smiles': 'CCC'}  create  12
# 12  {'id': 1, 'order': 0, 'fragment_id': 'f89b3c7a...  create  13
# 13  {'id': 2, 'order': 1, 'fragment_id': 'b2ea629f...  create  14
#
#                     timestamp               type  user_id  \
# 0  2019-06-24 12:50:04.141505           molecule        1
# 1  2019-06-24 12:50:04.215284           molecule        1
# 2  2019-06-24 12:50:05.663229           molecule        1
# 3  2019-06-24 12:50:05.696646           molecule        1
# 4  2019-06-24 12:50:05.696646           molecule        1
# 5  2019-06-24 12:50:05.696646           molecule        1
# 6  2019-06-24 12:50:07.036020           molecule        1
# 7  2019-06-24 12:50:07.036020           molecule        1
# 8  2019-06-24 12:50:07.036020           molecule        1
# 9  2019-06-24 12:50:07.814670           molecule        1
# 10 2019-06-24 12:50:08.580389           fragment        1
# 11 2019-06-24 12:50:08.622059           fragment        1
# 12 2019-06-24 12:50:08.649079  molecule_fragment        1
# 13 2019-06-24 12:50:08.678458  molecule_fragment        1
#
#                                     uuid
# 0   d12075e9-b918-4b33-8135-ae2c3b04337b
# 1   00f65f13-06fb-420e-b535-657d2a714f0a
# 2   2d312c7e-b44d-4252-9110-673fc963f505
# 3   d12075e9-b918-4b33-8135-ae2c3b04337b
# 4   00f65f13-06fb-420e-b535-657d2a714f0a
# 5   2d312c7e-b44d-4252-9110-673fc963f505
# 6   d12075e9-b918-4b33-8135-ae2c3b04337b
# 7   00f65f13-06fb-420e-b535-657d2a714f0a
# 8   2d312c7e-b44d-4252-9110-673fc963f505
# 9   024c4524-d24b-497b-b01a-71f29cbd5e8f
# 10  f89b3c7a-8350-48af-811c-4821448df1a5
# 11  b2ea629f-88c5-4f7d-a220-ccd4de8b0ab7
# 12  747fbf3c-64ca-4cc9-ad10-41e73d15910a
# 13  e71b32b7-e752-4644-b248-5f556cbf903a

# %%
from datetime import datetime
client.rollback(datetime(1980, 4, 3))

# %%
client.get('eventstore').sort_values(by='id')
# Out:
#                                                  data           event  id  \
# 0                    {'id': 1, 'smiles': 'C1C=CC=C1'}          create   1
# 1                          {'id': 2, 'smiles': 'C#N'}          create   2
# 2                           {'id': 3, 'smiles': 'CC'}          create   3
# 3   {'id': 1, 'smiles': 'C1C=CC=C1', 'properties':...          update   4
# 4        {'id': 2, 'smiles': 'C#N', 'properties': {}}          update   5
# 5         {'id': 3, 'smiles': 'CC', 'properties': {}}          update   6
# 6                                                None          delete   7
# 7                                                None          delete   8
# 8                                                None          delete   9
# 9                       {'id': 4, 'smiles': 'CCCC#N'}          create  10
# 10                         {'id': 1, 'smiles': 'C#N'}          create  11
# 11                         {'id': 2, 'smiles': 'CCC'}          create  12
# 12  {'id': 1, 'order': 0, 'fragment_id': 'f89b3c7a...          create  13
# 13  {'id': 2, 'order': 1, 'fragment_id': 'b2ea629f...          create  14
# 20                  {'before': '1980-04-03T00:00:00'}  rollback-start  15
# 14                                                 {}          delete  16
# 15                                                 {}          delete  17
# 16                                                 {}          delete  18
# 17                                                 {}          delete  19
# 18                                                 {}          delete  20
# 19                  {'before': '1980-04-03T00:00:00'}    rollback-end  21
#
#                     timestamp               type  user_id  \
# 0  2019-06-24 12:50:04.141505           molecule        1
# 1  2019-06-24 12:50:04.215284           molecule        1
# 2  2019-06-24 12:50:05.663229           molecule        1
# 3  2019-06-24 12:50:05.696646           molecule        1
# 4  2019-06-24 12:50:05.696646           molecule        1
# 5  2019-06-24 12:50:05.696646           molecule        1
# 6  2019-06-24 12:50:07.036020           molecule        1
# 7  2019-06-24 12:50:07.036020           molecule        1
# 8  2019-06-24 12:50:07.036020           molecule        1
# 9  2019-06-24 12:50:07.814670           molecule        1
# 10 2019-06-24 12:50:08.580389           fragment        1
# 11 2019-06-24 12:50:08.622059           fragment        1
# 12 2019-06-24 12:50:08.649079  molecule_fragment        1
# 13 2019-06-24 12:50:08.678458  molecule_fragment        1
# 20 2019-06-24 12:50:08.940061               None        1
# 14 2019-06-24 12:50:08.940061  molecule_fragment        1
# 15 2019-06-24 12:50:08.940061  molecule_fragment        1
# 16 2019-06-24 12:50:08.940061           fragment        1
# 17 2019-06-24 12:50:08.940061           fragment        1
# 18 2019-06-24 12:50:08.940061           molecule        1
# 19 2019-06-24 12:50:08.940061               None        1
#
#                                     uuid
# 0   d12075e9-b918-4b33-8135-ae2c3b04337b
# 1   00f65f13-06fb-420e-b535-657d2a714f0a
# 2   2d312c7e-b44d-4252-9110-673fc963f505
# 3   d12075e9-b918-4b33-8135-ae2c3b04337b
# 4   00f65f13-06fb-420e-b535-657d2a714f0a
# 5   2d312c7e-b44d-4252-9110-673fc963f505
# 6   d12075e9-b918-4b33-8135-ae2c3b04337b
# 7   00f65f13-06fb-420e-b535-657d2a714f0a
# 8   2d312c7e-b44d-4252-9110-673fc963f505
# 9   024c4524-d24b-497b-b01a-71f29cbd5e8f
# 10  f89b3c7a-8350-48af-811c-4821448df1a5
# 11  b2ea629f-88c5-4f7d-a220-ccd4de8b0ab7
# 12  747fbf3c-64ca-4cc9-ad10-41e73d15910a
# 13  e71b32b7-e752-4644-b248-5f556cbf903a
# 20                                  None
# 14  e71b32b7-e752-4644-b248-5f556cbf903a
# 15  747fbf3c-64ca-4cc9-ad10-41e73d15910a
# 16  b2ea629f-88c5-4f7d-a220-ccd4de8b0ab7
# 17  f89b3c7a-8350-48af-811c-4821448df1a5
# 18  024c4524-d24b-497b-b01a-71f29cbd5e8f
# 19                                  None
