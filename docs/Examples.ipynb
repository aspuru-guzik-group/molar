# %% [markdown]
# # Examples

# %%
from mdb import MDBClient

client = MDBClient('localhost', 'postgres', '', 'molecdb')
# Out:
# /Users/tga/miniconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.user, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.calculation, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.conformation, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.software, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule_fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/lib/python3.6/site-packages/SQLAlchemy-1.3.5-py3.6-macosx-10.7-x86_64.egg/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.alembic_version, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)

# %% [markdown]
# ## Get, Add, Update, Delete

# %% [markdown]
# There are four main methods in the client: `add`, `get`, `update` and `delete`. They have been made to be relatively easy to use and accept many different inputs.
#
# Let say we want to add a molecule. To do so, we can use the `add` method, and read the results with `get`. The results is a pandas.DataFrame that corresponds to the table `molecule`. Indeed with this method you have to be aware of the scheme of the database.

# %%
data = {'smiles': 'C1C=CC=C1'}
client.add('molecule', data)
client.get('molecule')
# Out:
#                   created_on  id properties     smiles  \
# 0 2020-01-19 19:27:37.197789   1         {}  C1C=CC=C1
#
#                   updated_on                                  uuid
# 0 2020-01-19 19:27:37.197789  76c6d4c7-c8cc-4807-afa2-154541f5aca9

# %% [markdown]
# If we want to work with a pandas.DataFrame as an input, we can just change the input. The column of the dataframe have to corresponds to the fields of the sql table.

# %%
import pandas as pd

df = pd.DataFrame([{'smiles': 'C#N'}, {'smiles': 'CC'}])
df.head()
# Out:
#   smiles
# 0    C#N
# 1     CC

# %%
client.add('molecule', df)
df = client.get('molecule')
df
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 44.70it/s]
#                   created_on  id properties     smiles  \
# 0 2020-01-19 19:27:37.197789   1         {}  C1C=CC=C1
# 1 2020-01-19 19:27:37.298978   2         {}        C#N
# 2 2020-01-19 19:27:37.404864   3         {}         CC
#
#                   updated_on                                  uuid
# 0 2020-01-19 19:27:37.197789  76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 1 2020-01-19 19:27:37.298978  b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 2 2020-01-19 19:27:37.404864  618cbef6-0d4c-4a2f-b35d-5e30afd1159f

# %% [markdown]
# It is also possile to get a dataframe of a table, change some values and set it back to the database.

# %%
df.at[0, 'properties'] = {'new_prop': 'prop_value'}
df
# Out:
#                   created_on  id                  properties     smiles  \
# 0 2020-01-19 19:27:37.197789   1  {'new_prop': 'prop_value'}  C1C=CC=C1
# 1 2020-01-19 19:27:37.298978   2                          {}        C#N
# 2 2020-01-19 19:27:37.404864   3                          {}         CC
#
#                   updated_on                                  uuid
# 0 2020-01-19 19:27:37.197789  76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 1 2020-01-19 19:27:37.298978  b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 2 2020-01-19 19:27:37.404864  618cbef6-0d4c-4a2f-b35d-5e30afd1159f

# %%
client.update('molecule', df)
df = client.get('molecule')
df
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 1469.28it/s]
#                   created_on  id                  properties     smiles  \
# 0 2020-01-19 19:27:37.197789   1  {'new_prop': 'prop_value'}  C1C=CC=C1
# 1 2020-01-19 19:27:37.298978   2                          {}        C#N
# 2 2020-01-19 19:27:37.404864   3                          {}         CC
#
#                   updated_on                                  uuid
# 0 2020-01-19 19:27:37.436168  76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 1 2020-01-19 19:27:37.436168  b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 2 2020-01-19 19:27:37.436168  618cbef6-0d4c-4a2f-b35d-5e30afd1159f

# %% [markdown]
# The `delete` method can take either a single uuid or a list of uuids:

# %%
df = client.get('molecule')
client.delete('molecule', df['uuid'].tolist())
client.get('molecule')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Objects with relations and helper methods
#
# Of course, `add`, `get`, `update` and `delete` don't capture everything. The relationships between objects do not appear on the pandas.DataFrame and it may be burdensome to add these relationship by hand. This is why some helper methods have been implemented.
#
# It is recommended you use this method when you are adding data to the database instead of the base methods for all objects that have relationships.

# %%
client.add_molecule(fragment=['C#N', 'CCC'], smiles='CCCC#N')
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 61.51it/s]
# {'molecule': <sqlalchemy.ext.automap.eventstore at 0x1181e9208>,
#  'molecule_fragment': [<sqlalchemy.ext.automap.eventstore at 0x1181fcbe0>,
#   <sqlalchemy.ext.automap.eventstore at 0x1181e9ba8>]}

# %%
# two fragments have been added
client.get('fragment')
# Out:
#                   created_on  id properties smiles                 updated_on  \
# 0 2020-01-19 19:27:37.795124   1         {}    C#N 2020-01-19 19:27:37.795124
# 1 2020-01-19 19:27:37.836063   2         {}    CCC 2020-01-19 19:27:37.836063
#
#                                    uuid
# 0  81a5b055-23f7-44b8-9ad2-bd75d4497143
# 1  5bb15bf7-7a7d-49b1-a335-ec744f85ace7

# %%
# as well as the molecule
client.get('molecule')
# Out:
#                   created_on  id properties  smiles  \
# 0 2020-01-19 19:27:37.739821   4         {}  CCCC#N
#
#                   updated_on                                  uuid
# 0 2020-01-19 19:27:37.739821  4dbf7365-aad1-4759-8dd3-7a8a337bc6d1

# %%
# and the relationship binding the two
client.get('molecule_fragment')
# Out:
#                   created_on                           fragment_id  id  \
# 0 2020-01-19 19:27:37.867158  81a5b055-23f7-44b8-9ad2-bd75d4497143   1
# 1 2020-01-19 19:27:37.913660  5bb15bf7-7a7d-49b1-a335-ec744f85ace7   2
#
#                             molecule_id  order                 updated_on  \
# 0  4dbf7365-aad1-4759-8dd3-7a8a337bc6d1      0 2020-01-19 19:27:37.867158
# 1  4dbf7365-aad1-4759-8dd3-7a8a337bc6d1      1 2020-01-19 19:27:37.913660
#
#                                    uuid
# 0  52bf8db5-c7e2-42b1-a407-42cb343ebfbd
# 1  9bff32db-3ab0-4c70-8a4c-2143f3fd3afe

# %% [markdown]
# ## Filtering
#
# All of this would be rather useless if we did not have an efficient way of filtering data. This is made rather easy thanks to the postgresql database. By using `client.get_models()` you get the scheme of the database and filter them as if they were python objects:

# %%
models = client.get_models()

# %%
client.get('fragment', filters=[models.fragment.smiles == 'C#N'])
# Out:
#                   created_on  id properties smiles                 updated_on  \
# 0 2020-01-19 19:27:37.795124   1         {}    C#N 2020-01-19 19:27:37.795124
#
#                                    uuid
# 0  81a5b055-23f7-44b8-9ad2-bd75d4497143

# %% [markdown]
# You can also do more complex filtering, joining tables that are related:

# %%
client.get(['molecule', 'molecule_fragment', 'fragment'], filters=[models.fragment.smiles == 'C#N', 
                                                                   models.molecule_fragment.order == 0])
# Out:
#                   created_on  id properties  smiles  \
# 0 2020-01-19 19:27:37.739821   4         {}  CCCC#N
#
#                   updated_on                                  uuid
# 0 2020-01-19 19:27:37.739821  4dbf7365-aad1-4759-8dd3-7a8a337bc6d1

# %% [markdown]
# In the here-above example, you only get the first table, because a pandas.DataFrame is not really well suited to deal with relational objects. Fortunately, you can also output a `sqlalchemy` object that will incorportate this mapping.

# %%
molecule = client.get(['molecule', 'molecule_fragment', 'fragment'], dataframe=False)
print(molecule[0].smiles)
print(molecule[0].molecule_fragment_collection[0].order)
print(molecule[0].molecule_fragment_collection[0].fragment.smiles)
# Out:
# CCCC#N
# 0
# C#N

# %% [markdown]
# ## Rollback
#
# The advantage of using event sourcing is that you can rollback at any point of time. Here is a quick example:

# %%
client.get('eventstore')
# Out:
#                                                  data   event    id  \
# 0                    {'id': 1, 'smiles': 'C1C=CC=C1'}  create  2234
# 1                          {'id': 2, 'smiles': 'C#N'}  create  2235
# 2                           {'id': 3, 'smiles': 'CC'}  create  2236
# 3   {'id': 1, 'smiles': 'C1C=CC=C1', 'properties':...  update  2237
# 4        {'id': 2, 'smiles': 'C#N', 'properties': {}}  update  2238
# 5         {'id': 3, 'smiles': 'CC', 'properties': {}}  update  2239
# 6                                                None  delete  2240
# 7                                                None  delete  2241
# 8                                                None  delete  2242
# 9                       {'id': 4, 'smiles': 'CCCC#N'}  create  2243
# 10                         {'id': 1, 'smiles': 'C#N'}  create  2244
# 11                         {'id': 2, 'smiles': 'CCC'}  create  2245
# 12  {'id': 1, 'order': 0, 'fragment_id': '81a5b055...  create  2246
# 13  {'id': 2, 'order': 1, 'fragment_id': '5bb15bf7...  create  2247
#
#                     timestamp               type  user_id  \
# 0  2020-01-19 19:27:37.197789           molecule        1
# 1  2020-01-19 19:27:37.298978           molecule        1
# 2  2020-01-19 19:27:37.404864           molecule        1
# 3  2020-01-19 19:27:37.436168           molecule        1
# 4  2020-01-19 19:27:37.436168           molecule        1
# 5  2020-01-19 19:27:37.436168           molecule        1
# 6  2020-01-19 19:27:37.624624           molecule        1
# 7  2020-01-19 19:27:37.624624           molecule        1
# 8  2020-01-19 19:27:37.624624           molecule        1
# 9  2020-01-19 19:27:37.739821           molecule        1
# 10 2020-01-19 19:27:37.795124           fragment        1
# 11 2020-01-19 19:27:37.836063           fragment        1
# 12 2020-01-19 19:27:37.867158  molecule_fragment        1
# 13 2020-01-19 19:27:37.913660  molecule_fragment        1
#
#                                     uuid
# 0   76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 1   b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 2   618cbef6-0d4c-4a2f-b35d-5e30afd1159f
# 3   76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 4   b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 5   618cbef6-0d4c-4a2f-b35d-5e30afd1159f
# 6   76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 7   b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 8   618cbef6-0d4c-4a2f-b35d-5e30afd1159f
# 9   4dbf7365-aad1-4759-8dd3-7a8a337bc6d1
# 10  81a5b055-23f7-44b8-9ad2-bd75d4497143
# 11  5bb15bf7-7a7d-49b1-a335-ec744f85ace7
# 12  52bf8db5-c7e2-42b1-a407-42cb343ebfbd
# 13  9bff32db-3ab0-4c70-8a4c-2143f3fd3afe

# %%
from datetime import datetime
client.rollback(datetime(1980, 4, 3))

# %%
client.get('eventstore').sort_values(by='id')
# Out:
#                                                  data           event    id  \
# 0                    {'id': 1, 'smiles': 'C1C=CC=C1'}          create  2234
# 1                          {'id': 2, 'smiles': 'C#N'}          create  2235
# 2                           {'id': 3, 'smiles': 'CC'}          create  2236
# 3   {'id': 1, 'smiles': 'C1C=CC=C1', 'properties':...          update  2237
# 4        {'id': 2, 'smiles': 'C#N', 'properties': {}}          update  2238
# 5         {'id': 3, 'smiles': 'CC', 'properties': {}}          update  2239
# 6                                                None          delete  2240
# 7                                                None          delete  2241
# 8                                                None          delete  2242
# 9                       {'id': 4, 'smiles': 'CCCC#N'}          create  2243
# 10                         {'id': 1, 'smiles': 'C#N'}          create  2244
# 11                         {'id': 2, 'smiles': 'CCC'}          create  2245
# 12  {'id': 1, 'order': 0, 'fragment_id': '81a5b055...          create  2246
# 13  {'id': 2, 'order': 1, 'fragment_id': '5bb15bf7...          create  2247
# 20                  {'before': '1980-04-03T00:00:00'}  rollback-start  2248
# 14                                                 {}          delete  2249
# 15                                                 {}          delete  2250
# 16                                                 {}          delete  2251
# 17                                                 {}          delete  2252
# 18                                                 {}          delete  2253
# 19                  {'before': '1980-04-03T00:00:00'}    rollback-end  2254
#
#                     timestamp               type  user_id  \
# 0  2020-01-19 19:27:37.197789           molecule        1
# 1  2020-01-19 19:27:37.298978           molecule        1
# 2  2020-01-19 19:27:37.404864           molecule        1
# 3  2020-01-19 19:27:37.436168           molecule        1
# 4  2020-01-19 19:27:37.436168           molecule        1
# 5  2020-01-19 19:27:37.436168           molecule        1
# 6  2020-01-19 19:27:37.624624           molecule        1
# 7  2020-01-19 19:27:37.624624           molecule        1
# 8  2020-01-19 19:27:37.624624           molecule        1
# 9  2020-01-19 19:27:37.739821           molecule        1
# 10 2020-01-19 19:27:37.795124           fragment        1
# 11 2020-01-19 19:27:37.836063           fragment        1
# 12 2020-01-19 19:27:37.867158  molecule_fragment        1
# 13 2020-01-19 19:27:37.913660  molecule_fragment        1
# 20 2020-01-19 19:27:37.948632               None        1
# 14 2020-01-19 19:27:37.948632  molecule_fragment        1
# 15 2020-01-19 19:27:37.948632  molecule_fragment        1
# 16 2020-01-19 19:27:37.948632           fragment        1
# 17 2020-01-19 19:27:37.948632           fragment        1
# 18 2020-01-19 19:27:37.948632           molecule        1
# 19 2020-01-19 19:27:37.948632               None        1
#
#                                     uuid
# 0   76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 1   b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 2   618cbef6-0d4c-4a2f-b35d-5e30afd1159f
# 3   76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 4   b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 5   618cbef6-0d4c-4a2f-b35d-5e30afd1159f
# 6   76c6d4c7-c8cc-4807-afa2-154541f5aca9
# 7   b6d9e64a-f6d2-4b49-85f3-e8ff74a7d9ab
# 8   618cbef6-0d4c-4a2f-b35d-5e30afd1159f
# 9   4dbf7365-aad1-4759-8dd3-7a8a337bc6d1
# 10  81a5b055-23f7-44b8-9ad2-bd75d4497143
# 11  5bb15bf7-7a7d-49b1-a335-ec744f85ace7
# 12  52bf8db5-c7e2-42b1-a407-42cb343ebfbd
# 13  9bff32db-3ab0-4c70-8a4c-2143f3fd3afe
# 20                                  None
# 14  9bff32db-3ab0-4c70-8a4c-2143f3fd3afe
# 15  52bf8db5-c7e2-42b1-a407-42cb343ebfbd
# 16  5bb15bf7-7a7d-49b1-a335-ec744f85ace7
# 17  81a5b055-23f7-44b8-9ad2-bd75d4497143
# 18  4dbf7365-aad1-4759-8dd3-7a8a337bc6d1
# 19                                  None
