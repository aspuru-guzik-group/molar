# %% [markdown]
# # Examples

# %%
from mdb import MDBClient

client = MDBClient('localhost', 'postgres', '', 'madness')
# Out:
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.conformer, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.molecule_fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.software, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.alembic_version, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synth_fragment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synthesis, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synthesis_machine, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.lab, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.experiment, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.experiment_machine, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.experiment_type, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.data_unit, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.xy_data, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.calculation, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.calculation_type, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)
# /Users/tga/miniconda3/envs/mdb/lib/python3.6/site-packages/sqlalchemy/ext/declarative/clsregistry.py:129: SAWarning: This declarative base already contains a class with the same class name and module name as sqlalchemy.ext.automap.synth_molecule, and will be replaced in the string-lookup table.
#   % (item.__module__, item.__name__)

# %% [markdown]
# ## Get, Add, Update, Delete

# %% [markdown]
# There are four main methods in the client: `add`, `get`, `update` and `delete`. They have been made to be relatively easy to use and accept many different inputs.
#
# Let say we want to add a molecule. To do so, we can use the `add` method, and read the results with `get`. The results is a pandas.DataFrame that corresponds to the table `molecule`. Indeed with this method you have to be aware of the scheme of the database.

# %%
data = {'smiles': 'C1C=CC=C1'}
client.add('molecule', data)
client.get('molecule')
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  6.63it/s]
#                   created_on metadata  id     smiles  \
# 0 2020-02-05 15:39:49.797484       {}  12  C1C=CC=C1
#
#                   updated_on                                  uuid
# 0 2020-02-05 15:39:49.797484  7c99c0aa-a985-4055-8a89-62a569b6fccc

# %% [markdown]
# If we want to work with a pandas.DataFrame as an input, we can just change the input. The column of the dataframe have to corresponds to the fields of the sql table.

# %%
import pandas as pd

df = pd.DataFrame([{'smiles': 'C#N'}, {'smiles': 'CC'}])
df.head()
# Out:
#   smiles
# 0    C#N
# 1     CC

# %%
client.add('molecule', df)
df = client.get('molecule')
df
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 36.96it/s]
#                   created_on metadata  id     smiles  \
# 0 2020-02-05 15:39:49.797484       {}  12  C1C=CC=C1
# 1 2020-02-05 15:39:49.870092       {}  13        C#N
# 2 2020-02-05 15:39:50.024713       {}  14         CC
#
#                   updated_on                                  uuid
# 0 2020-02-05 15:39:49.797484  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 1 2020-02-05 15:39:49.870092  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 2 2020-02-05 15:39:50.024713  a02c4bca-eb9e-442a-b7a3-73ada714e3f7

# %% [markdown]
# It is also possile to get a dataframe of a table, change some values and set it back to the database.

# %%
df.at[0, 'metadata'] = {'new_prop': 'prop_value'}
df
# Out:
#                   created_on                    metadata  id     smiles  \
# 0 2020-02-05 15:39:49.797484  {'new_prop': 'prop_value'}  12  C1C=CC=C1
# 1 2020-02-05 15:39:49.870092                          {}  13        C#N
# 2 2020-02-05 15:39:50.024713                          {}  14         CC
#
#                   updated_on                                  uuid
# 0 2020-02-05 15:39:49.797484  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 1 2020-02-05 15:39:49.870092  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 2 2020-02-05 15:39:50.024713  a02c4bca-eb9e-442a-b7a3-73ada714e3f7

# %%
client.update('molecule', df)
df = client.get('molecule')
df
# Out:
# 3it [00:00, 42.57it/s]
#                   created_on                    metadata  id     smiles  \
# 0 2020-02-05 15:39:49.797484  {'new_prop': 'prop_value'}  12  C1C=CC=C1
# 1 2020-02-05 15:39:49.870092                          {}  13        C#N
# 2 2020-02-05 15:39:50.024713                          {}  14         CC
#
#                   updated_on                                  uuid
# 0 2020-02-05 15:39:50.062466  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 1 2020-02-05 15:39:50.210280  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 2 2020-02-05 15:39:50.210280  a02c4bca-eb9e-442a-b7a3-73ada714e3f7

# %% [markdown]
# The `delete` method can take either a single uuid or a list of uuids:

# %%
df = client.get('molecule')
client.delete('molecule', df['uuid'].tolist())
client.get('molecule')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Objects with relations and helper methods
#
# Of course, `add`, `get`, `update` and `delete` don't capture everything. The relationships between objects do not appear on the pandas.DataFrame and it may be burdensome to add these relationship by hand. This is why some helper methods have been implemented.
#
# It is recommended you use this method when you are adding data to the database instead of the base methods for all objects that have relationships.

# %%
# Adding fragments
client.add_fragment('ABC')
client.add_fragment('DEF')

# Adding molecule made of fragment ABC and DEF
client.add_molecule('ABCDEF', 
                    fragments_uuid=[client.get_uuid('fragment', smiles='ABC'),
                                    client.get_uuid('fragment', smiles='DEF')])

# %%
# two fragments have been added
client.get('fragment')
# Out:
#    id smiles                 updated_on                                  uuid  \
# 0   7    ABC 2020-02-05 15:39:50.419804  17396bee-dd8d-4b27-b7a4-0ebe6a509153
# 1   8    DEF 2020-02-05 15:39:50.471218  134e7878-d8bb-4c6c-94a1-5094236fd3b0
#
#                   created_on properties
# 0 2020-02-05 15:39:50.419804         {}
# 1 2020-02-05 15:39:50.471218         {}

# %%
# as well as the molecule
client.get('molecule')
# Out:
#                   created_on metadata  id  smiles                 updated_on  \
# 0 2020-02-05 15:39:50.490832       {}  15  ABCDEF 2020-02-05 15:39:50.490832
#
#                                    uuid
# 0  b5c50345-69da-4857-a545-a9506c07c53b

# %%
# and the relationship binding the two
client.get('molecule_fragment')
# Out:
#    order                           molecule_id  \
# 0      0  b5c50345-69da-4857-a545-a9506c07c53b
# 1      1  b5c50345-69da-4857-a545-a9506c07c53b
#
#                                    uuid                 created_on  \
# 0  2026d086-c84f-4d7b-b213-ffc31440127f 2020-02-05 15:39:50.521969
# 1  f46edfe8-4390-4ab0-8190-d1dd3074262c 2020-02-05 15:39:50.521969
#
#                             fragment_id  id                 updated_on
# 0  17396bee-dd8d-4b27-b7a4-0ebe6a509153   3 2020-02-05 15:39:50.521969
# 1  134e7878-d8bb-4c6c-94a1-5094236fd3b0   4 2020-02-05 15:39:50.521969

# %% [markdown]
# **REMARK** There is no validation that the user provides a valid smiles to the database, or that it has been canonicalised.

# %% [markdown]
# ## Filtering
#
# All of this would be rather useless if we did not have an efficient way of filtering data. This is made rather easy thanks to the postgresql database. By using `client.get_models()` you get the scheme of the database and filter them as if they were python objects:

# %%
client.get('fragment', filters=[client.models.fragment.smiles == 'ABC'])
# Out:
#    id smiles                 updated_on                                  uuid  \
# 0   7    ABC 2020-02-05 15:39:50.419804  17396bee-dd8d-4b27-b7a4-0ebe6a509153
#
#                   created_on properties
# 0 2020-02-05 15:39:50.419804         {}

# %% [markdown]
# You can also do more complex filtering, joining tables that are related:

# %%
client.get(['molecule', 'molecule_fragment', 'fragment'], filters=[client.models.fragment.smiles == 'ABC', 
                                                                   client.models.molecule_fragment.order == 0])
# Out:
#                   created_on metadata  id  smiles                 updated_on  \
# 0 2020-02-05 15:39:50.490832       {}  15  ABCDEF 2020-02-05 15:39:50.490832
#
#                                    uuid
# 0  b5c50345-69da-4857-a545-a9506c07c53b

# %% [markdown]
# In the here-above example, you only get the first table, because a pandas.DataFrame is not really well suited to deal with relational objects. Fortunately, you can also output a `sqlalchemy` object that will incorportate this mapping.

# %%
molecule = client.get(['molecule', 'molecule_fragment', 'fragment'], return_df=False)
print(molecule[0].smiles)
print(molecule[0].molecule_fragment_collection[0].order)
print(molecule[0].molecule_fragment_collection[0].fragment.smiles)
# Out:
# ABCDEF
# 0
# ABC

# %% [markdown]
# ## Rollback
#
# The advantage of using event sourcing is that you can rollback at any point of time. Here is a quick example:

# %%
client.get('eventstore')
# Out:
#                  type  id                                  uuid  \
# 0            molecule  55  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 1            molecule  56  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 2            molecule  57  a02c4bca-eb9e-442a-b7a3-73ada714e3f7
# 3            molecule  58  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 4            molecule  59  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 5            molecule  60  a02c4bca-eb9e-442a-b7a3-73ada714e3f7
# 6            molecule  61  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 7            molecule  62  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 8            molecule  63  a02c4bca-eb9e-442a-b7a3-73ada714e3f7
# 9            fragment  64  17396bee-dd8d-4b27-b7a4-0ebe6a509153
# 10           fragment  65  134e7878-d8bb-4c6c-94a1-5094236fd3b0
# 11           molecule  66  b5c50345-69da-4857-a545-a9506c07c53b
# 12  molecule_fragment  67  2026d086-c84f-4d7b-b213-ffc31440127f
# 13  molecule_fragment  68  f46edfe8-4390-4ab0-8190-d1dd3074262c
#
#                                                  data   event  \
# 0                   {'id': 12, 'smiles': 'C1C=CC=C1'}  create
# 1                         {'id': 13, 'smiles': 'C#N'}  create
# 2                          {'id': 14, 'smiles': 'CC'}  create
# 3   {'id': 12, 'smiles': 'C1C=CC=C1', 'metadata': ...  update
# 4         {'id': 13, 'smiles': 'C#N', 'metadata': {}}  update
# 5          {'id': 14, 'smiles': 'CC', 'metadata': {}}  update
# 6                                                  {}  delete
# 7                                                  {}  delete
# 8                                                  {}  delete
# 9                          {'id': 7, 'smiles': 'ABC'}  create
# 10                         {'id': 8, 'smiles': 'DEF'}  create
# 11                     {'id': 15, 'smiles': 'ABCDEF'}  create
# 12  {'id': 3, 'order': 0, 'fragment_id': '17396bee...  create
# 13  {'id': 4, 'order': 1, 'fragment_id': '134e7878...  create
#
#                     timestamp
# 0  2020-02-05 15:39:49.797484
# 1  2020-02-05 15:39:49.870092
# 2  2020-02-05 15:39:50.024713
# 3  2020-02-05 15:39:50.062466
# 4  2020-02-05 15:39:50.210280
# 5  2020-02-05 15:39:50.210280
# 6  2020-02-05 15:39:50.274993
# 7  2020-02-05 15:39:50.372971
# 8  2020-02-05 15:39:50.372971
# 9  2020-02-05 15:39:50.419804
# 10 2020-02-05 15:39:50.471218
# 11 2020-02-05 15:39:50.490832
# 12 2020-02-05 15:39:50.521969
# 13 2020-02-05 15:39:50.521969

# %%
from datetime import datetime
client.rollback(datetime(1980, 4, 3))

# %%
client.get('eventstore').sort_values(by='id')
# Out:
#                  type  id                                  uuid  \
# 0            molecule  55  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 1            molecule  56  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 2            molecule  57  a02c4bca-eb9e-442a-b7a3-73ada714e3f7
# 3            molecule  58  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 4            molecule  59  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 5            molecule  60  a02c4bca-eb9e-442a-b7a3-73ada714e3f7
# 6            molecule  61  7c99c0aa-a985-4055-8a89-62a569b6fccc
# 7            molecule  62  1716c6af-47e4-4aa2-bc3d-068fa5e52a4f
# 8            molecule  63  a02c4bca-eb9e-442a-b7a3-73ada714e3f7
# 9            fragment  64  17396bee-dd8d-4b27-b7a4-0ebe6a509153
# 10           fragment  65  134e7878-d8bb-4c6c-94a1-5094236fd3b0
# 11           molecule  66  b5c50345-69da-4857-a545-a9506c07c53b
# 12  molecule_fragment  67  2026d086-c84f-4d7b-b213-ffc31440127f
# 13  molecule_fragment  68  f46edfe8-4390-4ab0-8190-d1dd3074262c
# 20               None  69                                  None
# 14  molecule_fragment  70  f46edfe8-4390-4ab0-8190-d1dd3074262c
# 15  molecule_fragment  71  2026d086-c84f-4d7b-b213-ffc31440127f
# 16           molecule  72  b5c50345-69da-4857-a545-a9506c07c53b
# 17           fragment  73  134e7878-d8bb-4c6c-94a1-5094236fd3b0
# 18           fragment  74  17396bee-dd8d-4b27-b7a4-0ebe6a509153
# 19               None  75                                  None
#
#                                                  data         event  \
# 0                   {'id': 12, 'smiles': 'C1C=CC=C1'}        create
# 1                         {'id': 13, 'smiles': 'C#N'}        create
# 2                          {'id': 14, 'smiles': 'CC'}        create
# 3   {'id': 12, 'smiles': 'C1C=CC=C1', 'metadata': ...        update
# 4         {'id': 13, 'smiles': 'C#N', 'metadata': {}}        update
# 5          {'id': 14, 'smiles': 'CC', 'metadata': {}}        update
# 6                                                  {}        delete
# 7                                                  {}        delete
# 8                                                  {}        delete
# 9                          {'id': 7, 'smiles': 'ABC'}        create
# 10                         {'id': 8, 'smiles': 'DEF'}        create
# 11                     {'id': 15, 'smiles': 'ABCDEF'}        create
# 12  {'id': 3, 'order': 0, 'fragment_id': '17396bee...        create
# 13  {'id': 4, 'order': 1, 'fragment_id': '134e7878...        create
# 20                  {'before': '1980-04-03T00:00:00'}      rollback
# 14                                                 {}        delete
# 15                                                 {}        delete
# 16                                                 {}        delete
# 17                                                 {}        delete
# 18                                                 {}        delete
# 19                  {'before': '1980-04-03T00:00:00'}  rollback-end
#
#                     timestamp
# 0  2020-02-05 15:39:49.797484
# 1  2020-02-05 15:39:49.870092
# 2  2020-02-05 15:39:50.024713
# 3  2020-02-05 15:39:50.062466
# 4  2020-02-05 15:39:50.210280
# 5  2020-02-05 15:39:50.210280
# 6  2020-02-05 15:39:50.274993
# 7  2020-02-05 15:39:50.372971
# 8  2020-02-05 15:39:50.372971
# 9  2020-02-05 15:39:50.419804
# 10 2020-02-05 15:39:50.471218
# 11 2020-02-05 15:39:50.490832
# 12 2020-02-05 15:39:50.521969
# 13 2020-02-05 15:39:50.521969
# 20 2020-02-05 15:39:50.550901
# 14 2020-02-05 15:39:50.550901
# 15 2020-02-05 15:39:50.550901
# 16 2020-02-05 15:39:50.550901
# 17 2020-02-05 15:39:50.550901
# 18 2020-02-05 15:39:50.550901
# 19 2020-02-05 15:39:50.550901

# %%
client.get('molecule')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
client.get('fragment')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Experimental data
#
# ... TODO ...
